# %%
import pandas_datareader.data as web 
import pandas as pd 
import datetime as dt 
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import style 

style.use("ggplot")

# %%
df = pd.read_excel("C:\\Users\\dmontoya006\\Downloads\\brent-crude-oil-prices-10-year-daily-chart.xlsx")
prices = df["value"]
daily_returns = prices.pct_change()
last_price = prices[2539]
last_price
# Out:
# 94.64

# %%
# Number of simulations 
num_simulations = 5000
num_days = 1260 
simulation_df = pd.DataFrame()

# %%
## 5 years
for x in range(num_simulations):
    count = 0 
    daily_SD = daily_returns.std()
    
    price_series = []
    
    price = last_price * (1 + np.random.normal(0,daily_SD))
    price_series.append(price)
    
    for y in range(num_days):
        if count == 1259:
            break 
        price = price_series[count] * (1 + np.random.normal(0,daily_SD))
        price_series.append(price)
        count += 1 
    
    simulation_df[x] = price_series

# %%
# x axis = number of simulations 
# y axis = number of days. 
simulation_df.head(-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3d8cad18fe3> in <module>
#       1 # x axis = number of simulations
#       2 # y axis = number of days.
# ----> 3 simulation_df.head(-1)
#
# NameError: name 'simulation_df' is not defined

# %%
fig = plt.figure(figsize=(12,7))
plt.plot(simulation_df)
plt.show()

# %%
num_simulations = 5000
num_days = 250 
simulation_df_1y = pd.DataFrame()

# %%
## 1 Years
for x in range(num_simulations):
    count = 0 
    daily_SD = daily_returns.std()
    
    price_series = []
    
    price = last_price * (1 + np.random.normal(0,daily_SD))
    price_series.append(price)
    
    for y in range(num_days):
        if count == 249:
            break 
        price = price_series[count] * (1 + np.random.normal(0,daily_SD))
        price_series.append(price)
        count += 1 
    
    simulation_df_1y[x] = price_series

# %%
# x axis = number of simulations 
# y axis = number of days. 
simulation_df_1y.head(-1)
# Out:
#            0          1          2           3           4           5     \
# 0     89.733758  95.770621  95.832992   99.762357   95.324065   95.431744
# 1     88.041341  96.390707  96.688074  101.664716  100.630983   93.679713
# 2     90.598974  89.679560  91.788158   98.903616  100.790885   97.651611
# 3     91.467644  86.106297  90.818689   98.928514   95.752993   94.444392
# 4     90.809299  90.046996  90.797546   98.794364   98.618267   94.004888
# ..          ...        ...        ...         ...         ...         ...
# 244  113.868305  62.125805  45.087718   48.065242  118.232884  101.429136
# 245  114.503211  59.860218  45.046790   47.684541  123.129155   99.991739
# 246  116.075267  62.391198  44.377843   50.983311  116.968448  101.527562
# 247  115.129189  61.480114  45.483811   50.951033  118.643425   99.441304
# 248  119.602496  62.207870  45.643535   50.284049  114.420097   97.608418
#
#            6           7          8          9     ...        4990       4991  \
# 0     98.011339   94.449844  93.226570  95.378960  ...   98.576630  92.348162
# 1     98.258335   96.858531  91.719642  95.077865  ...  100.539184  92.780184
# 2     97.767345  101.081162  92.447859  92.801405  ...  102.423724  92.909881
# 3     95.877963   98.085746  89.366591  96.338949  ...  109.478355  93.905423
# 4     96.767919   96.334158  86.711467  97.539778  ...  109.277910  91.624389
# ..          ...         ...        ...        ...  ...         ...        ...
# 244  114.004221   85.307895  95.851587  54.595368  ...   93.058059  87.212019
# 245  112.689856   81.733807  97.702687  56.182498  ...   93.355569  85.422658
# 246  110.917425   79.421195  92.285964  58.798697  ...   93.690645  88.519451
# 247  115.252890   78.487901  91.979812  63.412776  ...   94.520858  89.151988
# 248  118.409772   77.582519  91.027212  63.706180  ...   97.012406  92.319096
#
#            4992        4993        4994        4995        4996       4997  \
# 0     93.494087   93.589128   94.117900   94.556456   98.226172  87.064867
# 1     94.673994   93.622302   99.196078   96.126880   99.744561  86.419401
# 2     97.238416   93.248387  102.102749   98.991544  100.734612  91.740968
# 3     95.440973   96.040147  102.710056  100.105018  102.440261  89.100898
# 4     95.844111   91.616378  103.738256  100.113963  104.319933  88.853415
# ..          ...         ...         ...         ...         ...        ...
# 244  147.043718  103.770993  136.040400  141.710200   86.898768  82.475092
# 245  138.942622  105.557811  134.577604  142.330288   85.922731  80.736886
# 246  128.532545  106.662582  132.919268  146.697906   84.142965  82.564646
# 247  120.967791  102.205369  138.467509  151.705458   86.263559  83.225866
# 248  121.634831  100.015855  132.000403  157.869333   87.988209  81.048224
#
#            4998       4999
# 0     94.099207  90.267675
# 1    100.889204  85.869129
# 2     97.416547  83.711802
# 3     91.841946  82.797020
# 4     90.010967  81.345857
# ..          ...        ...
# 244  229.406079  55.730864
# 245  244.312817  56.279565
# 246  236.607935  54.793536
# 247  245.420700  53.779585
# 248  246.214788  52.726288
#
# [249 rows x 5000 columns]

# %%
num_simulations = 5000
num_days = 500 
simulation_df_2y = pd.DataFrame()

# %%
## 2 Years
for x in range(num_simulations):
    count = 0 
    daily_SD = daily_returns.std()
    
    price_series = []
    
    price = last_price * (1 + np.random.normal(0,daily_SD))
    price_series.append(price)
    
    for y in range(num_days):
        if count == 499:
            break 
        price = price_series[count] * (1 + np.random.normal(0,daily_SD))
        price_series.append(price)
        count += 1 
    
    simulation_df_2y[x] = price_series

# %%
# x axis = number of simulations 
# y axis = number of days. 
simulation_df_2y.head(-1)
# Out:
#           0          1           2          3          4           5     \
# 0    93.750205  95.963474  100.028590  92.364292  90.092809   91.695073
# 1    87.050064  94.159315  100.473087  92.007677  87.024275   93.657002
# 2    88.653997  94.477486  101.872079  90.757254  89.403909   96.420848
# 3    91.726855  94.943456  102.336869  93.069905  89.328512  102.297736
# 4    90.419924  93.725413  101.859798  90.689727  92.318688  102.476791
# ..         ...        ...         ...        ...        ...         ...
# 494  65.067968  55.862236   47.177241  41.341071  41.085792   43.536859
# 495  66.597925  54.813336   48.157192  43.136546  40.938385   41.896894
# 496  66.122025  56.464025   48.288854  45.132875  40.224931   42.261007
# 497  64.441510  56.098763   47.932176  44.921385  40.998667   42.742821
# 498  62.840522  55.782092   46.173589  46.040881  40.759273   42.374775
#
#           6           7           8           9     ...        4990  \
# 0    93.431544   93.833830   97.159485   97.720457  ...   98.088954
# 1    94.555792   94.853362  100.923805   94.020083  ...   94.244703
# 2    90.512253   99.325458   99.853709   91.828375  ...   94.514832
# 3    91.170081  101.129306   99.130841   90.941801  ...   91.859867
# 4    87.966666  103.344410  101.623229   92.854151  ...   87.386654
# ..         ...         ...         ...         ...  ...         ...
# 494  74.747121  110.534636   45.787930  108.149780  ...  237.208299
# 495  73.670398  115.310881   44.988924  104.986836  ...  219.694146
# 496  72.032532  116.150114   45.804124  104.827895  ...  218.023296
# 497  71.982587  116.184579   45.694913  106.389301  ...  218.686644
# 498  73.887231  119.086777   46.337064  105.337338  ...  214.982165
#
#            4991        4992        4993        4994        4995       4996  \
# 0     93.737767   91.142485   94.997754  100.282473   92.579132  95.260761
# 1     94.484655   93.539209   98.252311   98.419611   93.587851  97.494118
# 2    100.979363   96.760061  103.571344   95.406728   97.592319  97.851222
# 3    106.852560  100.482839  102.328432   94.143270  102.551609  94.877632
# 4    106.709728  100.201107  108.849513   91.233422  105.360628  92.255870
# ..          ...         ...         ...         ...         ...        ...
# 494   31.460811   80.761179  122.842611  130.180956  103.833806  71.427323
# 495   31.239596   82.273250  123.046800  131.069729  105.450965  69.850519
# 496   30.515634   79.182272  117.597341  129.616838  105.939445  68.803769
# 497   29.839203   77.903504  118.853623  130.458437  100.230557  68.461353
# 498   29.794819   79.129439  118.225762  123.418317   99.896236  69.354290
#
#            4997        4998       4999
# 0     95.903119   95.142371  99.257758
# 1     96.455314   95.246556  96.485239
# 2     95.300633   99.340986  95.614162
# 3     98.506261  101.366999  95.287681
# 4    100.792204  103.643561  91.600460
# ..          ...         ...        ...
# 494  112.190525  102.089191  32.025471
# 495  112.229465   99.309102  31.056727
# 496  112.233097   98.604281  31.517804
# 497  112.546856   94.857305  30.185835
# 498  108.938142   90.383282  31.575314
#
# [499 rows x 5000 columns]

# %%
num_simulations = 5000
num_days = 750 
simulation_df_3y = pd.DataFrame()

# %%
## 3 Years 
for x in range(num_simulations):
    count = 0 
    daily_SD = daily_returns.std()
    
    price_series = []
    
    price = last_price * (1 + np.random.normal(0,daily_SD))
    price_series.append(price)
    
    for y in range(num_days):
        if count == 749:
            break 
        price = price_series[count] * (1 + np.random.normal(0,daily_SD))
        price_series.append(price)
        count += 1 
    
    simulation_df_3y[x] = price_series

# %%
# x axis = number of simulations 
# y axis = number of days. 
simulation_df_3y.head(-1)
# Out:
#           0           1           2          3           4          5     \
# 0    94.406540   94.109319   93.855614  95.219495   96.716248  89.555339
# 1    90.419113   92.342404   96.004447  95.184208   93.703863  90.155220
# 2    88.447251   95.662164   96.537983  95.517694   90.475541  88.402163
# 3    86.137321   97.628962   98.852010  93.483749   91.114767  89.615335
# 4    87.580071   97.195260  100.772336  95.036545   91.657358  89.898712
# ..         ...         ...         ...        ...         ...        ...
# 744  90.993153  114.695814   26.008146  93.509805  554.089475  77.455723
# 745  89.139733  112.880664   25.573499  92.836822  536.578396  81.722793
# 746  92.063557  112.189583   25.848799  91.110330  525.232812  79.612097
# 747  91.536255  117.451446   25.020430  92.468728  523.610569  75.201290
# 748  87.219846  118.086587   25.534790  95.648693  511.127299  76.050975
#
#            6          7           8          9     ...       4990       4991  \
# 0     97.314514  97.621145   96.010132  96.099573  ...  90.602771  95.408731
# 1     98.569669  98.882049   97.656644  90.400477  ...  91.566642  92.518116
# 2     99.709409  98.176408   96.161979  86.027356  ...  92.409347  96.740782
# 3     99.910915  94.012056   94.526011  84.218578  ...  93.242010  93.749247
# 4    103.428608  93.808353   93.733095  83.731082  ...  94.091002  96.771415
# ..          ...        ...         ...        ...  ...        ...        ...
# 744  205.171779  31.248496  134.507637  78.163512  ...  26.964435  87.295314
# 745  204.750069  31.339921  128.338676  80.336419  ...  27.762472  89.153811
# 746  204.358002  31.352636  126.160749  76.338901  ...  28.096320  90.459130
# 747  203.388396  33.688350  125.063220  77.940730  ...  28.567520  87.646789
# 748  216.289500  34.869061  122.859116  79.258627  ...  28.243549  86.862304
#
#            4992       4993        4994       4995        4996        4997  \
# 0     92.715142  94.801196   97.303519  91.047090   93.109845   92.475925
# 1     92.689543  97.269531   97.440693  96.467848   94.647410   90.231591
# 2     92.009246  97.427643   97.927287  97.109086   95.781671   85.692725
# 3     90.181747  92.595202  102.587631  95.401456   93.588885   84.753622
# 4     91.950961  94.915171   99.273209  98.870997   94.631057   85.014928
# ..          ...        ...         ...        ...         ...         ...
# 744  170.973670  60.620268   73.226537  63.202898  102.028882  159.467482
# 745  167.509300  57.685096   79.575992  64.638951   99.378439  157.696156
# 746  171.404096  56.916105   80.085472  65.781284   98.629959  163.140861
# 747  165.213734  55.738011   80.480434  70.208252  101.676293  161.109994
# 748  165.427148  52.406380   82.946801  66.632159  104.422736  160.685881
#
#           4998       4999
# 0    89.229971  98.419725
# 1    86.076624  96.634404
# 2    84.762581  97.484509
# 3    85.620523  93.121991
# 4    84.878623  93.862321
# ..         ...        ...
# 744  10.984691  79.971990
# 745  11.401074  80.067903
# 746  11.092158  80.422251
# 747  10.870134  78.093624
# 748  10.961108  77.794029
#
# [749 rows x 5000 columns]

# %%
num_simulations = 5000
num_days = 1000 
simulation_df_4y = pd.DataFrame()

# %%
## 4 Years
for x in range(num_simulations):
    count = 0 
    daily_SD = daily_returns.std()
    
    price_series = []
    
    price = last_price * (1 + np.random.normal(0,daily_SD))
    price_series.append(price)
    
    for y in range(num_days):
        if count == 999:
            break 
        price = price_series[count] * (1 + np.random.normal(0,daily_SD))
        price_series.append(price)
        count += 1 
